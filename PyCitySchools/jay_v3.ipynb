# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# school_data.head()

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
total_schools = school_data['school_name'].count()
student_count = school_data['size'].sum()
budget = school_data['budget'].sum()
math_avg = student_data['math_score'].mean()
reading_avg = student_data['reading_score'].mean()
student_math_70 = (student_data['math_score'] >= 70).sum() / student_count * 100
student_reading_70 = (student_data['reading_score'] >= 70).sum() / student_count * 100
math_pass70 = school_data_complete.loc[(school_data_complete['math_score'] >= 70)]
read_pass70 = school_data_complete.loc[(school_data_complete['reading_score'] >= 70)]
stu_pass_both = school_data_complete.loc[(school_data_complete['math_score'] >= 70) 
                                         & (school_data_complete['reading_score'] >= 70)]
# stu_m = student_data.loc[student_data['math_score'] >=90]
# student_data.loc[student_data['reading_score'] >=90]
overall = (len(stu_pass_both.index) / student_count) * 100 #using len(df.index) is a fast and efficient way to calculate the numebr of rows
len(stu_pass_both.index)
# math_pass70
# round(student_data['math_score'].mean(), 2)
# Out:
# 25528

# %%
dist_sum_df = pd.DataFrame({"Total Schools": [total_schools],
                            "Total Students": [student_count],
                            "Total Budget": [budget],
                            "Average Math Score": [math_avg],
                            "Average Reading Score": [reading_avg],
                            "% Passing Math": [student_math_70],
                            "% Passing Reading": [student_reading_70],
                            "% Overall Passing": [overall]})
                                               
dist_sum_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
school_data_complete['school_name'].value_counts()
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# create a base dataframe to merge new columns to using the school_data df
# delete the rows you don't need
school_summary = school_data
# del school_summary["School ID"]
sch_names = school_summary['school_name']
types = school_summary.groupby(['school_name'])['type']
# types = school_summary['type']
# types = pd.DataFrame(types)
# types

# %%
school_data_complete.groupby(['school_name', 'type'])

# %%
# create a groupby and assign it to a variable to do some of the calculations
# group_df = school_data_complete.groupby(['school_name'])['reading_score', 'math_score'] # this will output the columns you want by the index of school name, but it converts it into a tuple and not a list. Use this for exact output values when ready to summarize. 
group_df = school_data_complete.groupby(['school_name', 'type'])
group_df.mean()
# Out:
#                                 Student ID  reading_score  math_score  \
# school_name           type
# Bailey High School    District     20358.5      81.033963   77.048432
# Cabrera High School   Charter      16941.5      83.975780   83.061895
# Figueroa High School  District      4391.0      81.158020   76.711767
# Ford High School      District     36165.0      80.746258   77.102592
# Griffin High School   Charter      12995.5      83.816757   83.351499
# Hernandez High School District      9944.0      80.934412   77.289752
# Holden High School    Charter      23060.0      83.814988   83.803279
# Huang High School     District      1458.0      81.182722   76.629414
# Johnson High School   District     32415.0      80.966394   77.072464
# Pena High School      Charter      23754.5      84.044699   83.839917
# Rodriguez High School District     28035.0      80.744686   76.842711
# Shelton High School   Charter       6746.0      83.725724   83.359455
# ...

# %%
#Type DONE
#calculate total students at each school DONE
#calculate total school budgets DONE
# per student budget
# avg math DONE
# avg reading DONE
# % passing math DONE
# % passing reading DONE
# % overall passing
# combine all calculations into the groupby dataframe
# reset_index to just use the school_name as the index and it will put back the 'type' in the columns

# %%
# per student budget
school_size = group_df['size'].mean()
school_budget = group_df['budget'].mean()
budget_per_stu = school_budget / school_size
budget_per_stu_df = pd.DataFrame(budget_per_stu, columns={'Per Student Budget'})
# test_df2 = pd.merge(test_df2, budget_per_stu_df, on='school_name')
# del test_df2['Per Student Budget_x']
# test_df2

# %%
# calculate school_avg_math
avg_math = group_df['math_score'].mean()
# merge it with the base df file 'school_summary' (do this when you have calculated all the values already)
test_df = pd.merge(school_summary, avg_math, on='school_name')
test_df #this is just a test to see if it works, the actual merge will be with the 'school_summary'
# Out:
#     School ID            school_name      type  size   budget  math_score
# 0           0      Huang High School  District  2917  1910635   76.629414
# 1           1   Figueroa High School  District  2949  1884411   76.711767
# 2           2    Shelton High School   Charter  1761  1056600   83.359455
# 3           3  Hernandez High School  District  4635  3022020   77.289752
# 4           4    Griffin High School   Charter  1468   917500   83.351499
# 5           5     Wilson High School   Charter  2283  1319574   83.274201
# 6           6    Cabrera High School   Charter  1858  1081356   83.061895
# 7           7     Bailey High School  District  4976  3124928   77.048432
# 8           8     Holden High School   Charter   427   248087   83.803279
# 9           9       Pena High School   Charter   962   585858   83.839917
# 10         10     Wright High School   Charter  1800  1049400   83.682222
# 11         11  Rodriguez High School  District  3999  2547363   76.842711
# ...

# %%
# avg reading
avg_reading = group_df['reading_score'].mean()
test_df2 = pd.merge(test_df, avg_reading, on='school_name')
avg_reading
# Out:
# school_name            type
# Bailey High School     District    81.033963
# Cabrera High School    Charter     83.975780
# Figueroa High School   District    81.158020
# Ford High School       District    80.746258
# Griffin High School    Charter     83.816757
# Hernandez High School  District    80.934412
# Holden High School     Charter     83.814988
# Huang High School      District    81.182722
# Johnson High School    District    80.966394
# Pena High School       Charter     84.044699
# Rodriguez High School  District    80.744686
# Shelton High School    Charter     83.725724
# Thomas High School     Charter     83.848930
# Wilson High School     Charter     83.989488
# Wright High School     Charter     83.955000
# Name: reading_score, dtype: float64

# %%
# % passing math. Use .loc and a conditional?
# student_math_70 = (student_data['math_score'] >= 70).sum() / student_count * 100
math_pass = school_data_complete.loc[school_data_complete["math_score"] >= 70]
math_group_pass = (math_pass.groupby(['school_name']).count()['math_score'] / group_df['size'].count()) *100
# test_df2 = pd.merge(avg_math, math_group_pass, on='school_name') #getting an error that 
math_group_pass_df = pd.DataFrame(math_group_pass, columns={'% Passing Math'})
test_df2 = pd.merge(test_df, math_group_pass_df, on='school_name') #getting an error that 
# test_df2.rename(columns={'0':'% Passing Math'}, inplace = True)
# test_df2

# %%
test_df2
# Out:
#     School ID            school_name      type  size   budget  math_score  \
# 0           0      Huang High School  District  2917  1910635   76.629414
# 1           1   Figueroa High School  District  2949  1884411   76.711767
# 2           2    Shelton High School   Charter  1761  1056600   83.359455
# 3           3  Hernandez High School  District  4635  3022020   77.289752
# 4           4    Griffin High School   Charter  1468   917500   83.351499
# 5           5     Wilson High School   Charter  2283  1319574   83.274201
# 6           6    Cabrera High School   Charter  1858  1081356   83.061895
# 7           7     Bailey High School  District  4976  3124928   77.048432
# 8           8     Holden High School   Charter   427   248087   83.803279
# 9           9       Pena High School   Charter   962   585858   83.839917
# 10         10     Wright High School   Charter  1800  1049400   83.682222
# 11         11  Rodriguez High School  District  3999  2547363   76.842711
# ...

# %%
# % passing reading
read_pass = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
read_group_pass = (read_pass.groupby(['school_name']).count()['reading_score'] / group_df['size'].count())*100
read_group_pass_df = pd.DataFrame(read_group_pass, columns={'% Passing Reading'})
test_df2 = pd.merge(test_df2, read_group_pass_df, on='school_name')

# %%
# % overall passing
stu_pass_both_count = stu_pass_both.groupby(['school_name']).count()['Student ID']
overall = (stu_pass_both_count / group_df['size'].count()) * 100
overall_df = pd.DataFrame(overall, columns={'% Overall Passing'})
test_df2 = pd.merge(test_df2, overall_df, on='school_name')

# %%
# groupby school name
school_summary_groupby = test_df2.groupby('school_name')
# school_summary_groupby_df = pd.DataFrame(school_summary_groupby)
# school_summary_groupby_df
test_df2
# Out:
#     School ID            school_name      type  size   budget  math_score  \
# 0           0      Huang High School  District  2917  1910635   76.629414
# 1           1   Figueroa High School  District  2949  1884411   76.711767
# 2           2    Shelton High School   Charter  1761  1056600   83.359455
# 3           3  Hernandez High School  District  4635  3022020   77.289752
# 4           4    Griffin High School   Charter  1468   917500   83.351499
# 5           5     Wilson High School   Charter  2283  1319574   83.274201
# 6           6    Cabrera High School   Charter  1858  1081356   83.061895
# 7           7     Bailey High School  District  4976  3124928   77.048432
# 8           8     Holden High School   Charter   427   248087   83.803279
# 9           9       Pena High School   Charter   962   585858   83.839917
# 10         10     Wright High School   Charter  1800  1049400   83.682222
# 11         11  Rodriguez High School  District  3999  2547363   76.842711
# ...

# %%
type(types)
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
#create df with school summary results
school_summary_df = pd.DataFrame({
#                             "School Name": sch_names,
#                             "School Type": types,
                            "Total Students": school_size,
                            "Total School Budget": school_budget,
                            "Per Student Budget": budget_per_stu,
                            "Average Math Score": avg_math,
                            "Average Reading Score": avg_reading,
                            "% Passing Math": math_group_pass,
                            "% Passing Reading": read_group_pass,
                            "% Overall Passing": overall
                            })

# school_summary_df = school_summary_df[['Total School Budget', 'Total Students']]

#formatting
school_summary_df.style.format({'Total Students' : "{:,}"
                                'Total School Budget' : "${:,}", 
#                                 "Per Student Budget": budget_per_stu,
#                                 "Average Math Score": avg_math,
#                                 "Average Reading Score": avg_reading,
#                                 "% Passing Math": math_group_pass,
#                                 "% Passing Reading": read_group_pass,
#                                 "% Overall Passing": overall
                         })
                                               
school_summary_df
# Out:
#   File "<ipython-input-19-c566c5c4ca50>", line 19
#     'Total School Budget' : "${:,}",
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_5 = school_summary_df.sort_values('% Overall Passing', ascending=False)
top_5.head()

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_5 = school_summary_df.sort_values('% Overall Passing', ascending=True)
bottom_5.head()

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
